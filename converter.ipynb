# %%
# file paths
sanctions_path = 'DisciplinarySanctions_b4fd5f7f-2575-4911-99a3-2c464103b4561756823407998.xlsx'

accumulation_path = 'AccumulatedCards_b4fd5f7f-2575-4911-99a3-2c464103b4561756823499455.xlsx'

# %%
import pandas as pd
from datetime import datetime

def write_suspension_reason(sent_off, event_type, match_event_subtype):
  if sent_off == 'No' and event_type == 'Yellow card':
    return 'Yellow-card accumulation'
  elif sent_off == 'Yes' and event_type == 'Yellow card':
    return 'Second caution'
  else:
    return match_event_subtype
  
def rewrite_club(club, serving_team):
  if type(serving_team) is str:
    return serving_team
  else:
    return club
  
def adjust_for_plurals(value, is_match):
  if is_match:
    if value == 1:
      return 'match'
    else:
      return 'matches'
  else:
    if value == 1:
      return 'month'
    else:
      return 'months'
    
def rewrite_values(value, is_match, is_not_months_for_remaining, return_date):
    if is_not_months_for_remaining:
      return return_date
    else:
      return f'{value} {adjust_for_plurals(value, is_match)}'
    
def rewrite_remaining(value, is_match, return_date):
  if is_match:
    return f'{value} {adjust_for_plurals(value, is_match)}'
  else:
    return_timestamp = pd.to_datetime(return_date).date()
    return return_timestamp

# %%
sanctions = pd.read_excel(sanctions_path)

sanctions = sanctions[sanctions['Competition type'].str.contains('L1 Cup|Ontario')]

sanctions = sanctions[sanctions['Case status'].str.contains('CONFIRMED')]

sanctions['Team'] = sanctions.apply(lambda x: rewrite_club(x['Club'], x['Serving team']), axis=1)

sanctions['Reason for Suspension'] = sanctions.apply(lambda x: write_suspension_reason(x['Sent off'], x['Event Type'], x['Match event sub-type']), axis=1)

sanctions['Reason for Suspension'] = sanctions['Reason for Suspension'].apply(lambda x: 'Denying an obvious goalscoring opportunity' if 'Denying an obvious goalscoring opportunity' in x else x)

sanctions['Sanction type'] = sanctions['Sanction type'].map(lambda x: True if x == 'Match suspension' else False)

sanctions['Value'] = sanctions.apply(lambda x: rewrite_values(x['Value'], x['Sanction type'], False, x['Sanction date to (EDT)']), axis=1)

sanctions['Remaining'] = sanctions.apply(lambda x: rewrite_remaining(x['Remaining'], x['Sanction type'], x['Sanction date to (EDT)']), axis=1)

sanctions = sanctions[['Club', 'Competition type', 'Person name', 'Offender type', 'Reason for Suspension', 'Value', 'Remaining']].sort_values(by=['Club'])

sanctions = sanctions.rename(columns={'Competition type': 'Competition', 'Person name': 'Name', 'Offender type': 'Person type', 'Value': 'Total suspended', 'Remaining': 'Total remaining'})

sanctions
# Out:
#                               Club                                Competition  \
# 18          BURLINGTON SC L2 WOMEN                        League2 Ontario (W)
# 44               BURLINGTON SC MEN       League1 Ontario Premier Division (M)
# 49      BURLINGTON SC U20 MEN EAST            League1 Ontario U-20 League (M)
# 48                   FC LONDON MEN       League1 Ontario Premier Division (M)
# 6              MASTER'S FA U20 MEN            League1 Ontario U-20 League (M)
# 7              MASTER'S FA U20 MEN            League1 Ontario U-20 League (M)
# 8              MASTER'S FA U20 MEN            League1 Ontario U-20 League (M)
# 11             MASTER'S FA U20 MEN            League1 Ontario U-20 League (M)
# 32        NORTH MISSISSAUGA SC MEN  League1 Ontario Championship Division (M)
# 29         NORTH TORONTO U20 WOMEN            League1 Ontario U-20 League (W)
# 42                 OAKVILLE SC MEN       League1 Ontario Premier Division (M)
# 2               PROSTARS FC L2 MEN                        League2 Ontario (M)
# 1         SCARBOROUGH TOWN U20 MEN            League1 Ontario U-20 League (M)
# 43                    SIGMA FC MEN       League1 Ontario Premier Division (M)
# 0   SIMCOE COUNTY ROVERS FC L2 MEN                        League2 Ontario (M)
# 5      SIMCOE COUNTY ROVERS FC MEN       League1 Ontario Premier Division (M)
# 3        ST CATHARINES ROMA L2 MEN                        League2 Ontario (M)
# 26       ST CATHARINES ROMA L2 MEN                        League2 Ontario (M)
# 4        ST CATHARINES ROMA L2 MEN                        League2 Ontario (M)
# 31          ST CATHARINES ROMA MEN       League1 Ontario Premier Division (M)
# 12           THE BOROUGH FC L2 MEN                        League2 Ontario (M)
# 39   UNIONVILLE MILLIKEN SC L2 MEN                        League2 Ontario (M)
# 9   UNIONVILLE MILLIKEN SC U20 MEN            League1 Ontario U-20 League (M)
# 45             VAUGHAN AZZURRI MEN       League1 Ontario Premier Division (M)
# 10          WATERLOO UNITED L2 MEN                        League2 Ontario (M)
# 30        WATERLOO UNITED L2 WOMEN                        League2 Ontario (W)
# 15               WHITBY FC U20 MEN            League1 Ontario U-20 League (M)
# 19               WHITBY FC U20 MEN            League1 Ontario U-20 League (M)
# 40             WINDSOR CITY FC MEN  League1 Ontario Championship Division (M)
# 41             WINDSOR CITY FC MEN  League1 Ontario Championship Division (M)
# 20             WINDSOR CITY FC MEN  League1 Ontario Championship Division (M)
# 17         WINDSOR CITY FC U20 MEN            League1 Ontario U-20 League (M)
# 21         WINDSOR CITY FC U20 MEN            League1 Ontario U-20 League (M)
# 46         WOODBRIDGE STRIKERS MEN       League1 Ontario Premier Division (M)
# 47         WOODBRIDGE STRIKERS MEN       League1 Ontario Premier Division (M)
#
#                              Name Person type  \
# 18                   WAYNE VIEIRA       Staff
# 44             GIANLUCA SPADAFORA      Player
# 49                    ROBERT GLOD      Player
# 48                 OBADA ABDALLAH      Player
# 6               ALEJANDRO MIRABEL      Player
# 7                    LUCA CALAMIA      Player
# 8              CRISTIANO VERRILLI      Player
# 11              SALVATORE TEDESCO      Player
# 32                  DANIEL BARKER      Player
# 29                  DAIRE O'BRIEN       Coach
# 42         ANTHONY RICARDO WRIGHT      Player
# 2                STEFANO SPAGNOLO      Player
# 1                 CYRIL LANGEVINE      Player
# 43                    DINO BONTIS      Player
# 0                     RYAN ZAMORA       Coach
# 5                   JUSTYN THOMAS      Player
# 3                     ETHAN PATRK      Player
# 26                    NOLAN FREEL      Player
# 4           CRISTIANO COLAMARTINI      Player
# 31              NICHOLAS ANDREOLA      Player
# 12                 LUIS PIGNATARI      Player
# 39                      ARI CITAK      Player
# 9               ARTEEN KHALATBARI      Player
# 45  ALEJANDRO MIGUEL PORTAL OLIVA      Player
# 10               MICHAEL GRIMALDI      Player
# 30                   SHALAGH GUHA      Player
# 15                GABRIEL MIKHAIL      Player
# 19        NATHAN HARRISON-BLOWERS      Player
# 40         MOUSTAPHA ADAMS KAMATE      Player
# 41                    PAOLO DAVIA      Player
# 20            JEFFERSON BOSIAKALI      Player
# 17       TOMAS ORBEGOZO HERNANDEZ      Player
# 21           EVAN MICHAEL LABUTTE      Player
# 46             ANTHONY AROMATARIO      Player
# 47                  CARMINE FIORE      Player
#
#                                 Reason for Suspension Total suspended  \
# 18                                     Second caution       2 matches
# 44  Using offensive, insulting or abusive language...         1 match
# 49  Using offensive, insulting or abusive language...       3 matches
# 48                           Yellow-card accumulation         1 match
# 6                                     Violent conduct       3 matches
# 7                                     Violent conduct       3 matches
# 8   Using offensive, insulting or abusive language...       3 matches
# 11                   Carryover suspension from indoor        8 months
# 32                                    Violent conduct       3 matches
# 29                                     Second caution       2 matches
# 42         Denying an obvious goalscoring opportunity       2 matches
# 2          Denying an obvious goalscoring opportunity       2 matches
# 1                                      Second caution         1 match
# 43         Denying an obvious goalscoring opportunity       0 matches
# 0   Using offensive, insulting or abusive language...       6 matches
# 5                                     Violent conduct       3 matches
# 3                                      Second caution         1 match
# 26                                    Violent conduct       2 matches
# 4                                      Second caution         1 match
# 31                                    Violent conduct       3 matches
# 12                                    Violent conduct       3 matches
# 39  Using offensive, insulting or abusive language...       7 matches
# 9                                   Serious foul play       2 matches
# 45  Using offensive, insulting or abusive language...         1 match
# 10                                     Second caution         1 match
# 30         Denying an obvious goalscoring opportunity       2 matches
# 15         Denying an obvious goalscoring opportunity       2 matches
# 19                                  Serious foul play       2 matches
# 40                           Yellow-card accumulation         1 match
# 41                           Yellow-card accumulation         1 match
# 20                                  Serious foul play       2 matches
# 17         Denying an obvious goalscoring opportunity       2 matches
# 21                           Yellow-card accumulation         1 match
# 46                           Yellow-card accumulation         1 match
# 47                           Yellow-card accumulation         1 match
#
#    Total remaining
# 18         1 match
# 44         1 match
# 49       3 matches
# 48         1 match
# 6          1 match
# 7        2 matches
# 8          1 match
# 11      2026-02-20
# 32         1 match
# 29       2 matches
# 42       2 matches
# 2          1 match
# 1          1 match
# 43       0 matches
# 0        6 matches
# 5          1 match
# 3          1 match
# 26       2 matches
# 4          1 match
# 31       2 matches
# 12         1 match
# 39       7 matches
# 9        2 matches
# 45         1 match
# 10         1 match
# 30       2 matches
# 15         1 match
# 19       2 matches
# 40         1 match
# 41         1 match
# 20         1 match
# 17         1 match
# 21         1 match
# 46         1 match
# 47         1 match

# %%
last_updated = pd.DataFrame({ 'Club': ['Last updated:'], 'Competition': [datetime.today().strftime('%Y-%m-%d')]})

sanctions = pd.concat([sanctions, last_updated], ignore_index=True)

sanctions.to_csv('active_suspensions.csv', index=False)

# %%
pending_sanctions = pd.read_excel(sanctions_path)

pending_sanctions = pending_sanctions[pending_sanctions['Competition type'].str.contains('L1 Cup|Ontario')]

pending_sanctions = pending_sanctions[pending_sanctions['Case status'].str.contains('ENTERED')]

pending_sanctions['Pending since'] = pending_sanctions.apply(lambda x: pd.to_datetime(x['In status since (EDT)']).date(), axis=1)

pending_sanctions = pending_sanctions[['Parent Club', 'Person name', 'Offender type', 'Pending since']].sort_values(by=['Pending since'])

pending_sanctions = pending_sanctions.rename(columns={'Parent Club': 'Club', 'Person name': 'Name', 'Offender type': 'Person type'})

last_updated = pd.DataFrame({ 'Club': ['Last updated:'], 'Name': [datetime.today().strftime('%Y-%m-%d')]})

pending_sanctions = pd.concat([pending_sanctions, last_updated], ignore_index=True)

pending_sanctions.to_csv('pending_suspensions.csv', index=False)

pending_sanctions
# Out:
#                    Club                     Name Person type Pending since
# 0        THE BOROUGH FC  RYAN DENNIS SILVERSTEIN      Player    2025-08-30
# 1  NORTH TORONTO SOCCER            LUCA DI MARCO      Player    2025-08-30
# 2  NORTH TORONTO SOCCER           CYRUS ROLLOCKS      Player    2025-09-01
# 3         Last updated:               2025-09-01         NaN           NaN

# %%
yc_accumulation = pd.read_excel(accumulation_path)

yc_accumulation = yc_accumulation[yc_accumulation['Competition type'].str.contains('L1 Cup|Ontario')]

yc_accumulation['yc count'] = yc_accumulation.groupby(['Person name', 'Club', 'Type', 'Competition'])['Person name'].transform('count')

yc_accumulation = yc_accumulation[['Person name', 'Club', 'Type', 'Competition', 'yc count']]

yc_accumulation = yc_accumulation.drop_duplicates(subset=['Person name', 'Club', 'Type', 'Competition'], keep='last')

yc_accumulation = yc_accumulation[(
  ((yc_accumulation['Type'] == 'Team official') & (yc_accumulation['yc count'] >= 2)) |
  ((yc_accumulation['Type'] == 'Player') & (yc_accumulation['yc count'] == 4)) | 
  ((yc_accumulation['Type'] == 'Player') & (yc_accumulation['yc count'] >= 6))
)]

last_updated = pd.DataFrame({ 'Person name': 'Last updated:', 'Club': [datetime.today().strftime('%Y-%m-%d')]})

yc_accumulation = pd.concat([yc_accumulation, last_updated], ignore_index=True)

yc_accumulation = yc_accumulation.rename(columns={ 'Person name': 'Name', 'Type': 'Person type'})

yc_accumulation = yc_accumulation[['Name', 'Club', 'Person type', 'Competition']]

yc_accumulation.to_csv('yc_accumulation.csv', index=False)

yc_accumulation
# Out:
#             Name        Club Person type Competition
# 0  Last updated:  2025-09-01         NaN         NaN
