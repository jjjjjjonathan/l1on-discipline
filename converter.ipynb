# %%
import pandas as pd

def write_suspension_reason(sent_off, event_type, match_event_subtype):
  if sent_off == 'No' and event_type == 'Yellow card':
    return 'Yellow-card accumulation'
  elif sent_off == 'Yes' and event_type == 'Yellow card':
    return 'Second caution'
  else:
    return match_event_subtype

# %%
# file paths
sanctions_path = 'DisciplinarySanctions_b4fd5f7f-2575-4911-99a3-2c464103b4561756490406992.xlsx'

# %%
sanctions = pd.read_excel(sanctions_path)

sanctions = sanctions[sanctions['Competition type'].str.contains('L1 Cup|Ontario')]

sanctions['Reason for suspension'] = sanctions.apply(lambda x: write_suspension_reason(x['Sent off'], x['Event Type'], x['Match event sub-type']), axis=1)

sanctions[['Serving team', 'Person name', 'Reason for suspension']]
# Out:
# /home/on9/.pyenv/versions/3.12.1/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                       Serving team                    Person name  \
# 0   SIMCOE COUNTY ROVERS FC L2 MEN                    RYAN ZAMORA
# 1         SCARBOROUGH TOWN U20 MEN                CYRIL LANGEVINE
# 2               PROSTARS FC L2 MEN               STEFANO SPAGNOLO
# 3        ST CATHARINES ROMA L2 MEN                    ETHAN PATRK
# 4        ST CATHARINES ROMA L2 MEN          CRISTIANO COLAMARTINI
# 5      SIMCOE COUNTY ROVERS FC MEN                  JUSTYN THOMAS
# 6              MASTER'S FA U20 MEN              ALEJANDRO MIRABEL
# 7              MASTER'S FA U20 MEN                   LUCA CALAMIA
# 8              MASTER'S FA U20 MEN             CRISTIANO VERRILLI
# 9   UNIONVILLE MILLIKEN SC U20 MEN              ARTEEN KHALATBARI
# 10          WATERLOO UNITED L2 MEN               MICHAEL GRIMALDI
# 11                             NaN              SALVATORE TEDESCO
# 12           THE BOROUGH FC L2 MEN                 LUIS PIGNATARI
# 15               WHITBY FC U20 MEN                GABRIEL MIKHAIL
# 17          WINDSOR CITY FC L2 MEN       TOMAS ORBEGOZO HERNANDEZ
# 18          BURLINGTON SC L2 WOMEN                   WAYNE VIEIRA
# 19               WHITBY FC U20 MEN        NATHAN HARRISON-BLOWERS
# 20             WINDSOR CITY FC MEN            JEFFERSON BOSIAKALI
# 21         WINDSOR CITY FC U20 MEN           EVAN MICHAEL LABUTTE
# 26       ST CATHARINES ROMA L2 MEN                    NOLAN FREEL
# 29         NORTH TORONTO U20 WOMEN                  DAIRE O'BRIEN
# 30        WATERLOO UNITED L2 WOMEN                   SHALAGH GUHA
# 31          ST CATHARINES ROMA MEN              NICHOLAS ANDREOLA
# 32        NORTH MISSISSAUGA SC MEN                  DANIEL BARKER
# 39                             NaN                      ARI CITAK
# 40             WINDSOR CITY FC MEN         MOUSTAPHA ADAMS KAMATE
# 41             WINDSOR CITY FC MEN                    PAOLO DAVIA
# 42                 OAKVILLE SC MEN         ANTHONY RICARDO WRIGHT
# 43                    SIGMA FC MEN                    DINO BONTIS
# 44               BURLINGTON SC MEN             GIANLUCA SPADAFORA
# 45             VAUGHAN AZZURRI MEN  ALEJANDRO MIGUEL PORTAL OLIVA
# 46         WOODBRIDGE STRIKERS MEN             ANTHONY AROMATARIO
# 47         WOODBRIDGE STRIKERS MEN                  CARMINE FIORE
# 48                   FC LONDON MEN                 OBADA ABDALLAH
# 49      BURLINGTON SC U20 MEN EAST                    ROBERT GLOD
#
#                                 Reason for suspension
# 0   Using offensive, insulting or abusive language...
# 1                                      Second caution
# 2   Denying an obvious goalscoring opportunity to ...
# 3                                      Second caution
# 4                                      Second caution
# 5                                     Violent conduct
# 6                                     Violent conduct
# 7                                     Violent conduct
# 8   Using offensive, insulting or abusive language...
# 9                                   Serious foul play
# 10                                     Second caution
# 11                                                NaN
# 12                                    Violent conduct
# 15  Denying an obvious goalscoring opportunity to ...
# 17  Denying an obvious goalscoring opportunity to ...
# 18                                     Second caution
# 19                                  Serious foul play
# 20                                  Serious foul play
# 21                           Yellow-card accumulation
# 26                                    Violent conduct
# 29                                     Second caution
# 30  Denying an obvious goalscoring opportunity to ...
# 31                                    Violent conduct
# 32                                    Violent conduct
# 39                                                NaN
# 40                           Yellow-card accumulation
# 41                           Yellow-card accumulation
# 42  Denying an obvious goalscoring opportunity to ...
# 43  Denying an obvious goalscoring opportunity to ...
# 44  Using offensive, insulting or abusive language...
# 45  Using offensive, insulting or abusive language...
# 46                           Yellow-card accumulation
# 47                           Yellow-card accumulation
# 48                           Yellow-card accumulation
# 49  Using offensive, insulting or abusive language...
